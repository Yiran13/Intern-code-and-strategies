# %% [markdown]
# ### 数据导出
# 1分钟周期

# %%
from record import DynamicResidualModelStrategy
from datetime import datetime
from vnpy.app.portfolio_strategy import BacktestingEngine
from vnpy.trader.constant import Interval
import pandas as pd
from pyecharts.charts import (Bar,Line,Graph,Gauge,Page)#柱状图，折线图，关系图，仪表盘,多图同表
from pyecharts import options as opts
import numpy as np
import random
import talib

# %%
engine = BacktestingEngine()
engine.clear_data()

engine.set_parameters(
    vt_symbols=["HC888.SHFE", 'RB888.SHFE'],
    interval=Interval.MINUTE,
    start=datetime(2014, 12, 31),
    end=datetime(2019, 5, 14),
    rates={"HC888.SHFE": 5/10000, "RB888.SHFE": 5/10000},
    slippages={"HC888.SHFE":2, "RB888.SHFE":1},
    sizes={"HC888.SHFE":10, "RB888.SHFE":10},
    priceticks={"HC888.SHFE":2, "RB888.SHFE":1},
    capital=1_000_0,
    collection_names={"HC888.SHFE":"HC888", "RB888.SHFE":"RB888"}

)
engine.add_strategy(DynamicResidualModelStrategy, {'price_add':20})
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
# Out:
# 2020-05-14 13:11:12.948753	开始加载历史数据
# 2020-05-14 13:11:13.669823	HC888.SHFE加载进度： [2%]
# 2020-05-14 13:11:14.260377	HC888.SHFE加载进度： [4%]
# 2020-05-14 13:11:15.043282	HC888.SHFE加载进度： [6%]
# 2020-05-14 13:11:15.803292	HC888.SHFE加载进度： [8%]
# 2020-05-14 13:11:16.589186	HC888.SHFE加载进度： [9%]
# 2020-05-14 13:11:17.337112	HC888.SHFE加载进度：# [11%]
# 2020-05-14 13:11:18.357383	HC888.SHFE加载进度：# [13%]
# 2020-05-14 13:11:19.311003	HC888.SHFE加载进度：# [15%]
# 2020-05-14 13:11:20.029047	HC888.SHFE加载进度：# [17%]
# 2020-05-14 13:11:20.711224	HC888.SHFE加载进度：# [19%]
# 2020-05-14 13:11:21.709589	HC888.SHFE加载进度：## [21%]
# 2020-05-14 13:11:22.606191	HC888.SHFE加载进度：## [23%]
# 2020-05-14 13:11:23.359171	HC888.SHFE加载进度：## [24%]
# 2020-05-14 13:11:23.927657	HC888.SHFE加载进度：## [26%]
# 2020-05-14 13:11:24.787362	HC888.SHFE加载进度：## [28%]
# 2020-05-14 13:11:25.576288	HC888.SHFE加载进度：### [30%]
# 2020-05-14 13:11:26.127930	HC888.SHFE加载进度：### [32%]
# 2020-05-14 13:11:26.750265	HC888.SHFE加载进度：### [34%]
# 2020-05-14 13:11:27.448356	HC888.SHFE加载进度：### [36%]
# 2020-05-14 13:11:27.969945	HC888.SHFE加载进度：### [38%]
# 2020-05-14 13:11:28.615260	HC888.SHFE加载进度：### [39%]
# 2020-05-14 13:11:29.051112	HC888.SHFE加载进度：#### [41%]
# 2020-05-14 13:11:29.597648	HC888.SHFE加载进度：#### [43%]
# 2020-05-14 13:11:30.279783	HC888.SHFE加载进度：#### [45%]
# 2020-05-14 13:11:30.810330	HC888.SHFE加载进度：#### [47%]
# 2020-05-14 13:11:31.388696	HC888.SHFE加载进度：#### [49%]
# 2020-05-14 13:11:31.922409	HC888.SHFE加载进度：##### [51%]
# 2020-05-14 13:11:32.435999	HC888.SHFE加载进度：##### [53%]
# 2020-05-14 13:11:33.125191	HC888.SHFE加载进度：##### [55%]
# 2020-05-14 13:11:33.616267	HC888.SHFE加载进度：##### [56%]
# 2020-05-14 13:11:34.323375	HC888.SHFE加载进度：##### [58%]
# 2020-05-14 13:11:34.892013	HC888.SHFE加载进度：###### [60%]
# 2020-05-14 13:11:35.470469	HC888.SHFE加载进度：###### [62%]
# 2020-05-14 13:11:36.018002	HC888.SHFE加载进度：###### [64%]
# 2020-05-14 13:11:36.593525	HC888.SHFE加载进度：###### [66%]
# 2020-05-14 13:11:37.161441	HC888.SHFE加载进度：###### [68%]
# 2020-05-14 13:11:37.847680	HC888.SHFE加载进度：###### [70%]
# 2020-05-14 13:11:38.394258	HC888.SHFE加载进度：####### [71%]
# 2020-05-14 13:11:38.821158	HC888.SHFE加载进度：####### [73%]
# 2020-05-14 13:11:39.516629	HC888.SHFE加载进度：####### [75%]
# 2020-05-14 13:11:39.984419	HC888.SHFE加载进度：####### [77%]
# 2020-05-14 13:11:40.555966	HC888.SHFE加载进度：####### [79%]
# 2020-05-14 13:11:41.284018	HC888.SHFE加载进度：######## [81%]
# 2020-05-14 13:11:41.862477	HC888.SHFE加载进度：######## [83%]
# 2020-05-14 13:11:42.422240	HC888.SHFE加载进度：######## [85%]
# 2020-05-14 13:11:43.053516	HC888.SHFE加载进度：######## [87%]
# 2020-05-14 13:11:43.623011	HC888.SHFE加载进度：######## [88%]
# 2020-05-14 13:11:44.141786	HC888.SHFE加载进度：######### [90%]
# 2020-05-14 13:11:44.691277	HC888.SHFE加载进度：######### [92%]
# 2020-05-14 13:11:45.548984	HC888.SHFE加载进度：######### [94%]
# 2020-05-14 13:11:46.071586	HC888.SHFE加载进度：######### [96%]
# 2020-05-14 13:11:46.597177	HC888.SHFE加载进度：######### [98%]
# 2020-05-14 13:11:47.083958	HC888.SHFE加载进度：######### [100%]
# 2020-05-14 13:11:47.161750	HC888.SHFE加载进度：########## [100%]
# 2020-05-14 13:11:47.161750	HC888.SHFE历史数据加载完成，数据量：399705
# 2020-05-14 13:11:48.072826	RB888.SHFE加载进度： [2%]
# 2020-05-14 13:11:48.621362	RB888.SHFE加载进度： [4%]
# 2020-05-14 13:11:49.357428	RB888.SHFE加载进度： [6%]
# 2020-05-14 13:11:50.312836	RB888.SHFE加载进度： [8%]
# 2020-05-14 13:11:51.022971	RB888.SHFE加载进度： [9%]
# 2020-05-14 13:11:51.671198	RB888.SHFE加载进度：# [11%]
# 2020-05-14 13:11:52.683532	RB888.SHFE加载进度：# [13%]
# 2020-05-14 13:11:53.453432	RB888.SHFE加载进度：# [15%]
# 2020-05-14 13:11:54.351995	RB888.SHFE加载进度：# [17%]
# 2020-05-14 13:11:54.894577	RB888.SHFE加载进度：# [19%]
# 2020-05-14 13:11:55.672651	RB888.SHFE加载进度：## [21%]
# 2020-05-14 13:11:56.438745	RB888.SHFE加载进度：## [23%]
# 2020-05-14 13:11:57.377380	RB888.SHFE加载进度：## [24%]
# 2020-05-14 13:11:57.955874	RB888.SHFE加载进度：## [26%]
# 2020-05-14 13:11:58.725774	RB888.SHFE加载进度：## [28%]
# 2020-05-14 13:11:59.420919	RB888.SHFE加载进度：### [30%]
# 2020-05-14 13:12:00.266618	RB888.SHFE加载进度：### [32%]
# 2020-05-14 13:12:00.786270	RB888.SHFE加载进度：### [34%]
# 2020-05-14 13:12:01.374826	RB888.SHFE加载进度：### [36%]
# 2020-05-14 13:12:01.905372	RB888.SHFE加载进度：### [38%]
# 2020-05-14 13:12:02.755133	RB888.SHFE加载进度：### [39%]
# 2020-05-14 13:12:03.192962	RB888.SHFE加载进度：#### [41%]
# 2020-05-14 13:12:03.737468	RB888.SHFE加载进度：#### [43%]
# 2020-05-14 13:12:04.336867	RB888.SHFE加载进度：#### [45%]
# 2020-05-14 13:12:04.862459	RB888.SHFE加载进度：#### [47%]
# 2020-05-14 13:12:05.329209	RB888.SHFE加载进度：#### [49%]
# 2020-05-14 13:12:06.194907	RB888.SHFE加载进度：##### [51%]
# 2020-05-14 13:12:06.717642	RB888.SHFE加载进度：##### [53%]
# 2020-05-14 13:12:07.266213	RB888.SHFE加载进度：##### [55%]
# 2020-05-14 13:12:07.747923	RB888.SHFE加载进度：##### [56%]
# 2020-05-14 13:12:08.295423	RB888.SHFE加载进度：##### [58%]
# 2020-05-14 13:12:09.227929	RB888.SHFE加载进度：###### [60%]
# 2020-05-14 13:12:09.794602	RB888.SHFE加载进度：###### [62%]
# 2020-05-14 13:12:10.172591	RB888.SHFE加载进度：###### [64%]
# 2020-05-14 13:12:10.741224	RB888.SHFE加载进度：###### [66%]
# 2020-05-14 13:12:11.318683	RB888.SHFE加载进度：###### [68%]
# 2020-05-14 13:12:11.822333	RB888.SHFE加载进度：###### [70%]
# 2020-05-14 13:12:12.723921	RB888.SHFE加载进度：####### [71%]
# 2020-05-14 13:12:13.176812	RB888.SHFE加载进度：####### [73%]
# 2020-05-14 13:12:13.695462	RB888.SHFE加载进度：####### [75%]
# 2020-05-14 13:12:14.152399	RB888.SHFE加载进度：####### [77%]
# 2020-05-14 13:12:14.727898	RB888.SHFE加载进度：####### [79%]
# 2020-05-14 13:12:15.271541	RB888.SHFE加载进度：######## [81%]
# 2020-05-14 13:12:16.198099	RB888.SHFE加载进度：######## [83%]
# 2020-05-14 13:12:16.748587	RB888.SHFE加载进度：######## [85%]
# 2020-05-14 13:12:17.139543	RB888.SHFE加载进度：######## [87%]
# 2020-05-14 13:12:17.731958	RB888.SHFE加载进度：######## [88%]
# 2020-05-14 13:12:18.250611	RB888.SHFE加载进度：######### [90%]
# 2020-05-14 13:12:18.771219	RB888.SHFE加载进度：######### [92%]
# 2020-05-14 13:12:19.235935	RB888.SHFE加载进度：######### [94%]
# 2020-05-14 13:12:20.171434	RB888.SHFE加载进度：######### [96%]
# 2020-05-14 13:12:20.695073	RB888.SHFE加载进度：######### [98%]
# 2020-05-14 13:12:21.184723	RB888.SHFE加载进度：######### [100%]
# 2020-05-14 13:12:21.265549	RB888.SHFE加载进度：########## [100%]
# 2020-05-14 13:12:21.265549	RB888.SHFE历史数据加载完成，数据量：399705
# 2020-05-14 13:12:21.265549	所有历史数据加载完成
# 2020-05-14 13:12:21.734257	策略初始化完成
# 2020-05-14 13:12:21.734257	开始回放历史数据
# 2020-05-14 13:12:35.672028	历史数据回放结束
# 2020-05-14 13:12:35.674024	开始计算逐日盯市盈亏
# 2020-05-14 13:12:35.684994	逐日盯市盈亏计算完成
# 2020-05-14 13:12:35.684994	开始计算策略统计指标
# 2020-05-14 13:12:35.694967	------------------------------
# 2020-05-14 13:12:35.694967	首个交易日：	2014-12-31
# 2020-05-14 13:12:35.694967	最后交易日：	2019-05-13
# 2020-05-14 13:12:35.694967	总交易日：	1118
# 2020-05-14 13:12:35.694967	盈利交易日：	105
# 2020-05-14 13:12:35.694967	亏损交易日：	126
# 2020-05-14 13:12:35.694967	起始资金：	10,000.00
# 2020-05-14 13:12:35.694967	结束资金：	-3,582.27
# 2020-05-14 13:12:35.694967	总收益率：	-135.82%
# 2020-05-14 13:12:35.694967	年化收益：	-29.16%
# 2020-05-14 13:12:35.694967	最大回撤: 	-19,229.24
# 2020-05-14 13:12:35.694967	百分比最大回撤: -124.47%
# 2020-05-14 13:12:35.694967	最长回撤天数: 	1062
# 2020-05-14 13:12:35.694967	总盈亏：	-13,582.27
# 2020-05-14 13:12:35.694967	总手续费：	922.27
# 2020-05-14 13:12:35.694967	总滑点：	10,180.00
# 2020-05-14 13:12:35.694967	总成交金额：	1,844,550.00
# 2020-05-14 13:12:35.694967	总成交笔数：	224
# 2020-05-14 13:12:35.694967	日均盈亏：	-12.15
# 2020-05-14 13:12:35.694967	日均手续费：	0.82
# 2020-05-14 13:12:35.694967	日均滑点：	9.11
# 2020-05-14 13:12:35.694967	日均成交金额：	1,649.87
# 2020-05-14 13:12:35.694967	日均成交笔数：	0.2003577817531306
# 2020-05-14 13:12:35.694967	日均收益率：	0.08%
# 2020-05-14 13:12:35.694967	收益标准差：	8.99%
# 2020-05-14 13:12:35.694967	Sharpe Ratio：	0.13
# 2020-05-14 13:12:35.694967	收益回撤比：	-1.09
# 2020-05-14 13:12:35.695964	策略统计指标计算完成
# c:\vnstudio\lib\site-packages\pandas\core\series.py:856: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# {'start_date': datetime.date(2014, 12, 31),
#  'end_date': datetime.date(2019, 5, 13),
#  'total_days': 1118,
#  'profit_days': 105,
#  'loss_days': 126,
#  'capital': 10000,
#  'end_balance': -3582.2749999999996,
#  'max_drawdown': -19229.235,
#  'max_ddpercent': -124.46864081050886,
#  'max_drawdown_duration': 1062,
#  'total_net_pnl': -13582.274999999998,
#  'daily_net_pnl': -12.14872540250447,
#  'total_commission': 922.275,
#  'daily_commission': 0.824932915921288,
#  'total_slippage': 10180,
#  'daily_slippage': 9.105545617173524,
#  'total_turnover': 1844550.0,
#  'daily_turnover': 1649.865831842576,
#  'total_trade_count': 224,
#  'daily_trade_count': 0.2003577817531306,
#  'total_return': -135.82274999999998,
#  'annual_return': -29.15694096601073,
#  'daily_return': 0.07766922493254276,
#  'return_std': 8.985764731266697,
#  'sharpe_ratio': 0.13390584938413874,
#  'return_drawdown_ratio': -1.0912206409225327}

# %%
record_array = engine.strategy.spread_record
datetime_array = engine.strategy.datetime_record
export_df = pd.DataFrame({'datetime':datetime_array,'spread':record_array})
export_df.to_csv('HC_RB_1min.csv',index=False)

# %%
mean = pd.Series(talib.SMA(np.array(record_array),240*30))
std= pd.Series(np.sqrt(talib.VAR(np.array(record_array),240*30)))
multiplier = 3
boll_up = pd.Series(mean + multiplier *std)
boll_down = pd.Series(mean - multiplier *std)

# %%
export_df['mean'] = mean.shift()
export_df['std'] = std.shift()
export_df['boll_up'] = boll_up.shift()
export_df['boll_down'] = boll_down.shift()

# %%
export_df[['spread','boll_up','boll_down']].plot(figsize=(15,10))

# %%
export_df['touch_up'] = np.where(export_df['spread']>=export_df['boll_up'],1,0)
export_df['touch_down'] = np.where(export_df['spread']<=export_df['boll_down'],1,0)

# %%
export_df['ind'] = np.arange(export_df.shape[0])

# %%
touch_up_interval = export_df.loc[export_df['touch_up']==1]['ind'].diff()
touch_down_interval = export_df.loc[export_df['touch_down']==1]['ind'].diff()

# %%
touch_up_interval.describe()
# Out:
# count     6662.000000
# mean        56.773191
# std       1126.418893
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max      41878.000000
# Name: ind, dtype: float64

# %%
touch_down_interval.describe()
# Out:
# count     6606.000000
# mean        47.296549
# std       1150.188655
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max      52908.000000
# Name: ind, dtype: float64

# %% [markdown]
# 上轨和下轨布林带突破，每次触发的间隔只有２５％的频率是大于１分钟的。
# 这就说明了有很多虚假的信号。需要转变思路．

# %%
touch_up_ind = export_df.loc[export_df['touch_up']==1]['ind']
touch_up_interval = export_df.loc[export_df['touch_up']==1]['ind'].diff()
touch_up_df = pd.DataFrame({'touch_up_ind':touch_up_ind,'touch_up_interval':touch_up_interval})
touch_up_df.reset_index(inplace=True)

# %%
max_touch_up_interval_index = touch_up_df.loc[touch_up_df['touch_up_interval'] == touch_up_df['touch_up_interval'].max()].index[0]

# %%
max_boll_up_end = export_df.loc[int([touch_up_df.iloc[max_touch_up_interval_index]['touch_up_ind']][0])]['datetime']
max_boll_up_start = export_df.loc[int([touch_up_df.iloc[max_touch_up_interval_index]['touch_up_ind']][0]-touch_up_df['touch_up_interval'].max())]['datetime']

print(max_boll_up_start,  max_boll_up_end)
# Out:
# 2016-12-06 10:30:00 2017-06-12 11:13:00

# %%
datetime_export_data = export_df.set_index('datetime')

# %%
datetime_export_data[max_boll_up_start:max_boll_up_end][['spread','boll_up','boll_down']].plot(figsize=(15,10))

# %%
touch_down_ind = export_df.loc[export_df['touch_down']==1]['ind']
touch_down_interval = export_df.loc[export_df['touch_down']==1]['ind'].diff()

touch_down_df = pd.DataFrame({'touch_down_ind':touch_down_ind,'touch_down_interval':touch_down_interval})
touch_down_df.reset_index(inplace=True)

# %%
max_touch_down_interval_index = touch_down_df.loc[touch_down_df['touch_down_interval'] == touch_down_df['touch_down_interval'].max()].index[0]
# Out:
# Timestamp('2015-09-17 10:13:00')

# %%
max_boll_down_end = export_df.loc[int([touch_down_df.iloc[max_touch_down_interval_index]['touch_down_ind']][0])]['datetime']
max_boll_down_start = export_df.loc[int([touch_down_df.iloc[max_touch_down_interval_index]['touch_down_ind']][0]-touch_down_df['touch_down_interval'].max())]['datetime']
print(max_boll_down_start,max_boll_down_end)
# Out:
# 2015-09-17 10:13:00 2016-03-14 09:01:00

# %%
datetime_export_data[max_boll_down_start:max_boll_down_end][['spread','boll_up','boll_down','std']].plot(figsize=(15,10))

# %% [markdown]
# 测试return的收益率

# %%
import collections

Tradedata= collections.namedtuple('tradedata', ['trade_return','trade_type','trade_interval','start_date','close_date'])
# tradedata = Tradedata(trade_rertun,trade_type,trade_interval)

# %%
ind =1

# 持有周期
hold_ind = 20
profit_pct = 0.05
exit_pct = - 0.01

trade_record = []
while ind + hold_ind < touch_up_df.shape[0]:
    touch_up_interval = touch_up_df.iloc[ind,2]
    touch_up_ind = touch_up_df.iloc[ind,1]
    # 滞后买入
    open_position_ind = int(touch_up_ind + 1)
    # 要多拿一根bar的数据
    slice_df = export_df.iloc[open_position_ind:open_position_ind+hold_ind+2]
    # 买入后收益return
    pct_array = (slice_df['spread']-slice_df['spread'].iloc[0])/slice_df['spread'].iloc[0]

    #计算是否触碰止盈
    if np.where(pct_array[:-1]>=profit_pct)[0].size>0:
        profit_ind = np.where(pct_array[:-1]>=profit_pct)[0][0]
    else:
        profit_ind = None
    #计算是否触碰止损    
    if np.where(pct_array[:-1]<=exit_pct)[0].size>0:
        exit_ind = np.where(pct_array[:-1]<=exit_pct)[0][0]
    else:
        exit_ind = None

    # 计算最终收益
    # 由于是达到止盈之后，下一根bar才成交，因此最终的收益并不是就是大于等于止盈return的

    # 触及止盈和止损点位
    if profit_ind and exit_ind:
        if profit_ind<exit_ind:
            # 下一根bar
            trade_rertun = pct_array.iloc[profit_ind+1]
            trade_type =  'profit_exit'
            trade_interval = profit_ind
        else:
            trade_rertun = pct_array.iloc[exit_ind+1]
            trade_type = 'loss_exit'
            trade_interval = exit_ind

    # 止盈和止损都没触及

    elif not profit_ind and not exit_ind:
        trade_rertun = pct_array.iloc[-1]
        trade_type = 'time_exit'
        trade_interval = hold_ind

    # 只触及止盈

    elif profit_ind and not exit_ind:
        trade_rertun = pct_array.iloc[profit_ind+1]
        trade_type =  'profit_exit'
        trade_interval = profit_ind
    # 只触及止损

    elif not profit_ind and exit_ind:
        trade_rertun = pct_array.iloc[exit_ind+1]
        trade_type = 'loss_exit'
        trade_interval = exit_ind
    start_date = slice_df.iloc[0]['datetime']
    end_date = slice_df.iloc[trade_interval]['datetime']
    tradedata = Tradedata(trade_rertun,trade_type,trade_interval,start_date,end_date)
    trade_record.append(tradedata)
    ind = ind+trade_interval

# %%
loss_record = []
profit_record = []
time_record = []


for trade in trade_record:
    
    if trade.trade_type=='loss_exit':
        loss_record.append(trade)
    elif trade.trade_type=='time_exit':
        time_record.append(trade)    
    elif trade.trade_type == 'profit_exit':
        profit_record.append(trade)

# %%
len(loss_record),len(profit_record),len(time_record)
# Out:
# (381, 117, 221)

# %%
# loss 是否具有一些特征？
# 总的收益如何？
return_array = []
interval_array = []
for trade in trade_record:
    return_array.append(trade.trade_return)
    interval_array.append(trade.trade_interval)

return_array = np.array(return_array)+1
boll_up_buy_return_series =pd.Series(return_array.cumprod())

# %%
# 中间有大回撤
# 回撤多为连续的是否有什么原因？
#亏损时间
boll_up_buy_return_series.plot(figsize=(15,10))

# %%
# loss 是否具有一些特征？
# 总的收益如何？
return_array = []

interval_array = []
start_datetime_array = []
end_datetime_array = []

for trade in loss_record:
    return_array.append(trade.trade_return)
    interval_array.append(trade.trade_interval)
    start_datetime_array.append(trade.start_date)
    end_datetime_array.append(trade.close_date)

# %%
loss_start_date = pd.Series(start_datetime_array)
loss_end_date = pd.Series(end_datetime_array)
# end_datetime_array

# %%
# 只看一个就可以差别不大
# 大部分的亏损都是集中在一天
(loss_start_date.dt.date).value_counts()
# Out:
# 2015-07-22    66
# 2015-08-24    39
# 2015-12-14    37
# 2016-02-22    27
# 2015-07-23    25
# 2015-04-01    24
# 2015-12-31    18
# 2015-03-31    16
# 2016-05-23    12
# 2015-03-02    10
# 2015-12-30     8
# 2015-08-25     8
# 2015-12-29     7
# 2016-02-23     7
# 2016-01-04     7
# 2015-02-28     6
# 2015-04-23     5
# 2015-03-27     5
# 2015-02-27     4
# 2016-02-15     4
# 2016-02-16     4
# 2018-03-20     4
# 2016-11-01     4
# 2018-03-19     4
# 2015-12-21     3
# 2016-02-19     3
# 2016-12-02     3
# 2016-02-20     2
# 2017-10-12     2
# 2016-03-08     2
# 2017-09-04     2
# 2018-05-17     2
# 2016-05-24     2
# 2015-06-10     2
# 2015-06-11     1
# 2017-10-10     1
# 2018-03-16     1
# 2016-08-31     1
# 2016-10-31     1
# 2016-08-30     1
# 2018-10-22     1
# dtype: int64

# %%
# profit 是否具有一些特征？
# 总的收益如何？
return_array = []

interval_array = []
start_datetime_array = []
end_datetime_array = []

for trade in profit_record:
    return_array.append(trade.trade_return)
    interval_array.append(trade.trade_interval)
    start_datetime_array.append(trade.start_date)
    end_datetime_array.append(trade.close_date)

# %%
profit_start_date = pd.Series(start_datetime_array)
profit_end_date = pd.Series(end_datetime_array)

# %%
((profit_start_date.dt.date).value_counts())
# Out:
# 2015-07-22    34
# 2015-08-24    18
# 2015-12-14    14
# 2016-02-22    12
# 2015-07-23     9
# 2015-12-31     7
# 2015-12-29     4
# 2015-03-02     3
# 2015-12-30     2
# 2015-12-21     2
# 2015-04-01     2
# 2015-02-28     2
# 2015-03-31     2
# 2016-02-19     1
# 2016-02-15     1
# 2016-03-08     1
# 2016-05-23     1
# 2015-02-27     1
# 2016-02-20     1
# dtype: int64

# %%
return_array = []

interval_array = []
start_datetime_array = []
end_datetime_array = []

for trade in time_record:
    return_array.append(trade.trade_return)
    interval_array.append(trade.trade_interval)
    start_datetime_array.append(trade.start_date)
    end_datetime_array.append(trade.close_date)
    
time_start_date = pd.Series(start_datetime_array)
time_end_date = pd.Series(end_datetime_array)

# %%
((time_start_date.dt.date).value_counts())
# Out:
# 2019-01-10    17
# 2016-10-31    17
# 2018-10-23    17
# 2019-04-16    17
# 2019-04-15    17
# 2019-01-09    17
# 2018-10-22    16
# 2016-11-01    14
# 2016-03-07     9
# 2016-02-22     8
# 2016-03-08     7
# 2015-02-27     5
# 2016-08-31     5
# 2015-08-24     5
# 2016-02-23     4
# 2015-08-25     3
# 2016-05-23     3
# 2016-03-05     3
# 2015-04-01     3
# 2016-03-04     3
# 2015-03-31     3
# 2016-08-30     3
# 2016-12-02     2
# 2015-06-11     2
# 2017-10-12     2
# 2015-03-02     2
# 2018-03-20     2
# 2015-07-23     2
# 2018-10-24     2
# 2018-05-17     2
# 2016-02-20     2
# 2019-01-11     1
# 2018-05-18     1
# 2015-12-31     1
# 2017-10-10     1
# 2016-12-06     1
# 2015-06-10     1
# 2015-02-28     1
# dtype: int64

# %%
return_array = []

interval_array = []
start_datetime_array = []
end_datetime_array = []

for trade in trade_record:
    return_array.append(trade.trade_return)
    interval_array.append(trade.trade_interval)
    start_datetime_array.append(trade.start_date)
    end_datetime_array.append(trade.close_date)
    
trade_start_date = pd.Series(start_datetime_array)
trade_end_date = pd.Series(end_datetime_array)

# %%
#　一天多次的信号

((trade_start_date.dt.date).value_counts())
# Out:
# 2015-07-22    100
# 2015-08-24     62
# 2015-12-14     51
# 2016-02-22     47
# 2015-07-23     36
# 2015-04-01     29
# 2015-12-31     26
# 2015-03-31     21
# 2016-10-31     18
# 2016-11-01     18
# 2019-04-16     17
# 2019-01-09     17
# 2018-10-23     17
# 2019-04-15     17
# 2019-01-10     17
# 2018-10-22     17
# 2016-05-23     16
# 2015-03-02     15
# 2015-12-29     11
# 2016-02-23     11
# 2015-08-25     11
# 2015-02-27     10
# 2016-03-08     10
# 2015-12-30     10
# 2016-03-07      9
# 2015-02-28      9
# 2016-01-04      7
# 2016-08-31      6
# 2018-03-20      6
# 2016-02-15      5
# 2016-12-02      5
# 2016-02-20      5
# 2015-04-23      5
# 2015-03-27      5
# 2015-12-21      5
# 2017-10-12      4
# 2018-03-19      4
# 2018-05-17      4
# 2016-02-19      4
# 2016-02-16      4
# 2016-08-30      4
# 2016-03-05      3
# 2015-06-11      3
# 2016-03-04      3
# 2015-06-10      3
# 2017-09-04      2
# 2016-05-24      2
# 2017-10-10      2
# 2018-10-24      2
# 2016-12-06      1
# 2019-01-11      1
# 2018-03-16      1
# 2018-05-18      1
# dtype: int64
