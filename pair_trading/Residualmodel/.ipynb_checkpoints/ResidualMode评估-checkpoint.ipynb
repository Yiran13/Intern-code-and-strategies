# %%
from ResidualStrategy_simple_dynamic_record import DynamicResidualModelStrategy
from datetime import datetime
from vnpy.app.portfolio_strategy import BacktestingEngine
from vnpy.trader.constant import Interval
import pandas as pd
from pyecharts.charts import (Bar,Line,Graph,Gauge,Page)#柱状图，折线图，关系图，仪表盘,多图同表
from pyecharts import options as opts
import numpy as np
import random

# %%
engine = BacktestingEngine()

engine.set_parameters(
    vt_symbols=["HC888.SHFE", 'RB888.SHFE'],
    interval=Interval.MINUTE,
    start=datetime(2019, 3, 31 ),
    end=datetime(2020, 3, 1),
    rates={"HC888.SHFE": 5/10000, "RB888.SHFE": 5/10000},
    slippages={"HC888.SHFE":2, "RB888.SHFE": 10},
    sizes={"HC888.SHFE":10, "RB888.SHFE":10},
    priceticks={"HC888.SHFE":2, "RB888.SHFE":10},
    capital=1_000_0,
    collection_names={"HC888.SHFE":"HC888", "RB888.SHFE":"RB888"}

)
engine.add_strategy(DynamicResidualModelStrategy, {'entry_multiplier': 2.7,'std_window': 1000, 'difference_filter_num': 60，'difference_exit_num':0})
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
#
# Out:
# 2020-05-12 22:29:35.911469	开始加载历史数据
# 2020-05-12 22:29:35.914459	HC888.SHFE加载进度： [9%]
# 2020-05-12 22:29:35.917453	HC888.SHFE加载进度：# [18%]
# 2020-05-12 22:29:35.921405	HC888.SHFE加载进度：## [27%]
# 2020-05-12 22:29:35.926392	HC888.SHFE加载进度：### [36%]
# 2020-05-12 22:29:35.930380	HC888.SHFE加载进度：#### [45%]
# 2020-05-12 22:29:35.933372	HC888.SHFE加载进度：##### [54%]
# 2020-05-12 22:29:35.937362	HC888.SHFE加载进度：###### [62%]
# 2020-05-12 22:29:35.941351	HC888.SHFE加载进度：####### [71%]
# 2020-05-12 22:29:35.946345	HC888.SHFE加载进度：######## [80%]
# 2020-05-12 22:29:35.950327	HC888.SHFE加载进度：######## [89%]
# 2020-05-12 22:29:35.954316	HC888.SHFE加载进度：######### [98%]
# 2020-05-12 22:29:35.954316	HC888.SHFE加载进度：########## [100%]
# 2020-05-12 22:29:35.954316	HC888.SHFE历史数据加载完成，数据量：73350
# 2020-05-12 22:29:35.958306	RB888.SHFE加载进度： [9%]
# 2020-05-12 22:29:35.962295	RB888.SHFE加载进度：# [18%]
# 2020-05-12 22:29:35.969313	RB888.SHFE加载进度：## [27%]
# 2020-05-12 22:29:35.973296	RB888.SHFE加载进度：### [36%]
# 2020-05-12 22:29:35.978254	RB888.SHFE加载进度：#### [45%]
# 2020-05-12 22:29:35.983239	RB888.SHFE加载进度：##### [54%]
# 2020-05-12 22:29:35.986232	RB888.SHFE加载进度：###### [62%]
# 2020-05-12 22:29:35.991218	RB888.SHFE加载进度：####### [71%]
# 2020-05-12 22:29:35.995207	RB888.SHFE加载进度：######## [80%]
# 2020-05-12 22:29:35.999196	RB888.SHFE加载进度：######## [89%]
# 2020-05-12 22:29:36.001191	RB888.SHFE加载进度：######### [98%]
# 2020-05-12 22:29:36.002189	RB888.SHFE加载进度：########## [100%]
# 2020-05-12 22:29:36.002189	RB888.SHFE历史数据加载完成，数据量：73350
# 2020-05-12 22:29:36.002189	所有历史数据加载完成
# 时间2019-04-08 09:00:00 多开 多HC888.SHFE 1 手 空RB888.SHFE 1 手 价差[-4.16111145]
# 时间2019-04-08 09:01:00 多开 多HC888.SHFE 1 手 空RB888.SHFE 1 手 价差[-5
00 多开 多HC888.SHFE 2 手 空RB888.SHFE 1 手 价差[-111.97613274]
# 时间2019-11-19 09:00:00 多平 rebalance 平多HC888.SHFE 2 手 平空RB888.SHFE 1 手 价差[-33.88681835]
# 时间2019-11-20 14:46:00 多开 多HC888.SHFE 2 手 空RB888.SHFE 1 手 价差[-140.89172717]
# 时间2019-11-21 11:26:00 多平 调参 平多HC888.SHFE 2 手 平空RB888.SHFE 1 手 价差[-79.88067237]
# 时间2019-12-10 09:00:00 多开 多HC888.SHFE 1 手 空RB888.SHFE 1 手 价差[-10.53860654]
# 时间2019-12-17 09:00:00 多平 rebalance 平多HC888.SHFE 1 手 平空RB888.SHFE 1 手 价差[17.22472035]
# 2020-05-12 22:29:39.416258	历史数据回放结束
# 2020-05-12 22:29:39.417256	开始计算逐日盯市盈亏
# 2020-05-12 22:29:39.422242	逐日盯市盈亏计算完成
# 2020-05-12 22:29:39.422242	开始计算策略统计指标
# 2020-05-12 22:29:39.428227	------------------------------
# 2020-05-12 22:29:39.428227	首个交易日：	2019-04-01
# 2020-05-12 22:29:39.428227	最后交易日：	2020-02-28
# 2020-05-12 22:29:39.428227	总交易日：	222
# 2020-05-12 22:29:39.428227	盈利交易日：	9
# 2020-05-12 22:29:39.428227	亏损交易日：	12
# 2020-05-12 22:29:39.428227	起始资金：	10,000.00
# 2020-05-12 22:29:39.428227	结束资金：	7,943.56
# 2020-05-12 22:29:39.428227	总收益率：	-20.56%
# 2020-05-12 22:29:39.428227	年化收益：	-22.23%
# 2020-05-12 22:29:39.428227	最大回撤: 	-2,359.53
# 2020-05-12 22:29:39.428227	百分比最大回撤: -23.60%
# 2020-05-12 22:29:39.428227	最长回撤天数: 	233
# 2020-05-12 22:29:39.428227	总盈亏：	-2,056.45
# 2020-05-12 22:29:39.428227	总手续费：	826.44
# 2020-05-12 22:29:39.428227	总滑点：	2,440.00
# 2020-05-12 22:29:39.428227	总成交金额：	1,652,890.00
# 2020-05-12 22:29:39.428227	总成交笔数：	36
# 2020-05-12 22:29:39.428227	日均盈亏：	-9.26
# 2020-05-12 22:29:39.428227	日均手续费：	3.72
# 2020-05-12 22:29:39.428227	日均滑点：	10.99
# 2020-05-12 22:29:39.428227	日均成交金额：	7,445.45
# 2020-05-12 22:29:39.428227	日均成交笔数：	0.16216216216216217
# 2020-05-12 22:29:39.428227	日均收益率：	-0.10%
# 2020-05-12 22:29:39.428227	收益标准差：	1.18%
# 2020-05-12 22:29:39.428227	Sharpe Ratio：	-1.36
# 2020-05-12 22:29:39.428227	收益回撤比：	-0.87
# 2020-05-12 22:29:39.428227	策略统计指标计算完成
# {'start_date': datetime.date(2019, 4, 1),
#  'end_date': datetime.date(2020, 2, 28),
#  'total_days': 222,
#  'profit_days': 9,
#  'loss_days': 12,
#  'capital': 10000,
#  'end_balance': 7943.555,
#  'max_drawdown': -2359.5299999999997,
#  'max_ddpercent': -23.595299999999998,
#  'max_drawdown_duration': 233,
#  'total_net_pnl': -2056.445,
#  'daily_net_pnl': -9.263265765765766,
#  'total_commission': 826.4449999999999,
#  'daily_commission': 3.7227252252252248,
#  'total_slippage': 2440,
#  'daily_slippage': 10.99099099099099,
#  'total_turnover': 1652890.0,
#  'daily_turnover': 7445.45045045045,
#  'total_trade_count': 36,
#  'daily_trade_count': 0.16216216216216217,
#  'total_return': -20.56445,
#  'annual_return': -22.231837837837837,
#  'daily_return': -0.10370458781082446,
#  'return_std': 1.177813098047756,
#  'sharpe_ratio': -1.3640403292589045,
#  'return_drawdown_ratio': -0.8715485711137388}

# %%
spread_datetime_list = engine.strategy.record_array
boll_up_datetime_list = engine.strategy.record_boll_up
boll_down_datetime_list = engine.strategy.record_boll_down


datetime_list = [ spread_datetime[0] for spread_datetime in spread_datetime_list]
spread_list = [ spread_datetime[1] for spread_datetime in spread_datetime_list]
diff_list = [ spread_datetime[2] for spread_datetime in spread_datetime_list]

datetime_boll_up_list = [ boll_up_datetime[0] for boll_up_datetime in boll_up_datetime_list]
boll_up_list = [  boll_up_datetime[1] for boll_up_datetime in boll_up_datetime_list]

datetime_boll_down_list = [ boll_down_datetime[0] for boll_down_datetime in boll_down_datetime_list]
boll_down_list = [  boll_down_datetime[1] for boll_down_datetime in boll_down_datetime_list]

# %%
value_df = pd.DataFrame({'datetime':datetime_list,'residual':spread_list,'diff':diff_list})
boll_df = pd.DataFrame({'datetime':datetime_boll_up_list,'boll_up':boll_up_list,'boll_down':boll_down_list})
# value_df.set_index('datetime',inplace=True)

# %%
combine_df = pd.merge(left=value_df,right=boll_df)
combine_df = combine_df.iloc[10*240:]

# %%
combine_df.loc[combine_df['residual']>combine_df['boll_up']]

# %%
combine_df.loc[combine_df['residual']<combine_df['boll_down']]

# %%
bar_1 = Line()

start = 0
end = 20000
# 以时间作为x轴
bar_1.add_xaxis(combine_df['datetime'].tolist()[start:end],)
# y轴数据字符串表示，y轴数据list
bar_1.add_yaxis('OLS_residual',combine_df['residual'].tolist()[start:end])
bar_1.add_yaxis('boll_up',combine_df['boll_up'].tolist()[start:end])
bar_1.add_yaxis('boll_down',combine_df['boll_down'].tolist()[start:end])
bar_1.set_series_opts(label_opts=opts.LabelOpts(is_show=False))  
bar_1.render_notebook()

# %%
bar_1 = Line()

start = 20000
end = 40000
# 以时间作为x轴
bar_1.add_xaxis(combine_df['datetime'].tolist()[start:end],)
# y轴数据字符串表示，y轴数据list
bar_1.add_yaxis('OLS_residual',combine_df['residual'].tolist()[start:end])
bar_1.add_yaxis('boll_up',combine_df['boll_up'].tolist()[start:end])
bar_1.add_yaxis('boll_down',combine_df['boll_down'].tolist()[start:end])
bar_1.set_series_opts(label_opts=opts.LabelOpts(is_show=False))  
bar_1.render_notebook()

# %%
bar_1 = Line()

start = 40000
end = 60000
# 以时间作为x轴
bar_1.add_xaxis(combine_df['datetime'].tolist()[start:end],)
# y轴数据字符串表示，y轴数据list
bar_1.add_yaxis('OLS_residual',combine_df['residual'].tolist()[start:end])
bar_1.add_yaxis('boll_up',combine_df['boll_up'].tolist()[start:end])
bar_1.add_yaxis('boll_down',combine_df['boll_down'].tolist()[start:end])
bar_1.set_series_opts(label_opts=opts.LabelOpts(is_show=False))  
bar_1.render_notebook()

# %%
bar_1 = Line()

start = 2000
end = 2300
# 以时间作为x轴
bar_1.add_xaxis(combine_df['datetime'].tolist()[start:end],)
# y轴数据字符串表示，y轴数据list
bar_1.add_yaxis('diff',combine_df['diff'].tolist()[start:end])
bar_1.set_series_opts(label_opts=opts.LabelOpts(is_show=False))  
bar_1.render_notebook()

# %%
combine_df['diff'].iloc[2500:3000].plot()

# %%
import statsmodels.tsa.stattools as ts
import statsmodels.api as sm

# %%
X = combine_df['residual']

y = combine_df['diff']

result = sm.OLS(y,X).fit()

# %%
result.params
